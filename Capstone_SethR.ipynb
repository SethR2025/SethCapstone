# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
import xlsxwriter

# %%
col_names = ['Rating', 'G1','G2','G3','G4','G5','G6','G7','G8','G9','G10','G11','G12'
            ,'G13','G14','B1','B2','B3','B4','B5','G15','G16', 'Cost']

# %%
hhc_by_state = pd.read_csv('data/Home_Health_Care_-_State_by_State_Data.csv', header=0, names= col_names)
hhc_by_state = hhc_by_state.drop(['B4'], axis=1)
hhc_by_state = hhc_by_state.drop(['B3'], axis=1)
hhc_by_state = hhc_by_state.drop(['G15'], axis=1)
hhc_by_state = hhc_by_state.drop(['Cost'], axis=1)
hhc_by_state = hhc_by_state.drop('GU')
hhc_by_state = hhc_by_state.drop('MP')
hhc_by_state = hhc_by_state.drop('VI')
hhc_by_state = hhc_by_state.drop('PR')
hhc_by_state.head(2)
# Out:
#    Rating    G1    G2    G3    G4    G5    G6    G7    G8    G9   G10   G11  \
# AK    2.0  90.2  94.2  99.5  93.8  62.4  72.1  96.4  64.5  67.2  65.0  59.2
# AL    4.0  97.9  99.4  99.8  97.4  78.6  80.4  99.0  83.0  81.6  86.3  88.2
#
#      G12   G13   G14    B1    B2   B5   G16
# AK  64.6  87.9  52.9  14.6  18.0  0.7  86.4
# AL  85.0  93.3  75.7  16.7  12.3  0.4  95.3

# %%
hhc_by_state.to_csv('hhc_state.csv')

# %%
hhc = pd.read_csv('hhc_state.csv')

# %%
bottom_states = pd.read_csv('data/Bottom5States.csv')
top_states = pd.read_csv('data/Top5States.csv')

# %%
bottom_states.head(2)
# Out:
#   State  CMS Certification Number (CCN)*                    Provider Name  \
# 0    AK                            27001      PROVIDENCE IN HOME SERVICES
# 1    AK                            27006  FAIRBANKS MEMORIAL HOSPITAL HHA
#
#                        Address       City    Zip       Phone  \
# 0  4001 DALE STREET, SUITE 101  ANCHORAGE  99508  9075630130
# 1              1701 GILLAM WAY  FAIRBANKS  99701  9074585410
#
#         Type of Ownership  Offers Nursing Care Services  \
# 0                   Local                            50
# 1  Hospital Based Program                            50
#
#    Offers Physical Therapy Services  Offers Occupational Therapy Services  \
# 0                                50                                    50
# 1                                50                                     0
#
#    Offers Speech Pathology Services  Offers Medical Social Services  \
# 0                                50                              50
# 1                                 0                              50
#
#    Offers Home Health Aide Services  HHCAHPS Survey Summary Star Rating  \
# 0                                50                                   3
# 1                                50                                   4
#
#    Star Rating for health team gave care in a professional way  \
# 0                                                  4
# 1                                                  4
#
#    Percent of patients who reported that their home health team gave care in a professional way  \
# 0                                                 89
# 1                                                 88
#
#    Star Rating for health team communicated well with them  \
# 0                                                  4
# 1                                                  4
#
#    Percent of patients who reported that their home health team communicated well with them  \
# 0                                                 87
# 1                                                 86
#
#    Star Rating team discussed medicines, pain, and home safety  \
# 0                                                  2
# 1                                                  4
#
#    Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them  \
# 0                                                 78
# 1                                                 85
#
#    Star Rating for how patients rated overall care from agency  \
# 0                                                  3
# 1                                                  4
#
#    Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)  \
# 0                                                 85
# 1                                                 84
#
#    Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family  \
# 0                                                 79
# 1                                                 89
#
#    Number of completed Surveys  Response rate  Total Score  Offers Score
# 0                          196             26          738           300
# 1                           51             21          832           200
